# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

# %%
data1=pd.read_csv("/Users/DELL/Desktop/salesdata.csv", engine='python')

# %%
data1
# Out:
#        transaction_id product_id                  product_description  \
# 0              536365     85123A   WHITE HANGING HEART T-LIGHT HOLDER
# 1              536365      71053                  WHITE METAL LANTERN
# 2              536365     84406B       CREAM CUPID HEARTS COAT HANGER
# 3              536365     84029G  KNITTED UNION FLAG HOT WATER BOTTLE
# 4              536365     84029E       RED WOOLLY HOTTIE WHITE HEART.
# 5              536365      22752         SET 7 BABUSHKA NESTING BOXES
# 6              536365      21730    GLASS STAR FROSTED T-LIGHT HOLDER
# 7              536366      22633               HAND WARMER UNION JACK
# 8              536366      22632            HAND WARMER RED POLKA DOT
# 9              536367      84879        ASSORTED COLOUR BIRD ORNAMENT
# 10             536367      22745           POPPY'S PLAYHOUSE BEDROOM
# 11             536367      22748            POPPY'S PLAYHOUSE KITCHEN
# ...

# %%
data1.describe()
# Out:
#        quantity_sold     unit_price    customer_id
# count  541909.000000  541909.000000  406829.000000
# mean        9.552250       4.611114   15287.690570
# std       218.081158      96.759853    1713.600303
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %%
for col in data1.columns: 
    print(col)
# Out:
# transaction_id
# product_id
# product_description
# quantity_sold
# transaction_timestamp
# unit_price
# customer_id
# transaction_country

# %%
print(data1.head())
# Out:
#   transaction_id product_id                  product_description  \
# 0         536365     85123A   WHITE HANGING HEART T-LIGHT HOLDER
# 1         536365      71053                  WHITE METAL LANTERN
# 2         536365     84406B       CREAM CUPID HEARTS COAT HANGER
# 3         536365     84029G  KNITTED UNION FLAG HOT WATER BOTTLE
# 4         536365     84029E       RED WOOLLY HOTTIE WHITE HEART.
#
#    quantity_sold transaction_timestamp  unit_price  customer_id  \
# 0              6        12/1/2010 8:26        2.55      17850.0
# 1              6        12/1/2010 8:26        3.39      17850.0
# 2              8        12/1/2010 8:26        2.75      17850.0
# 3              6        12/1/2010 8:26        3.39      17850.0
# 4              6        12/1/2010 8:26        3.39      17850.0
#
#   transaction_country
# 0      United Kingdom
# 1      United Kingdom
# 2      United Kingdom
# 3      United Kingdom
# 4      United Kingdom

# %%
data_Missing=data1.isnull().sum()

# %%
data_Missing
# Out:
# transaction_id                0
# product_id                    0
# product_description        1454
# quantity_sold                 0
# transaction_timestamp         0
# unit_price                    0
# customer_id              135080
# transaction_country           0
# dtype: int64

# %%
plt.scatter(data1['quantity_sold'],data1['unit_price'])
plt.show()

# %%
data1['quantity_sold'].value_counts()
# Out:
#  1        148227
#  2         81829
#  12        61063
#  6         40868
#  4         38484
#  3         37121
#  24        24021
#  10        22288
#  8         13129
#  5         11757
#  48         6068
#  25         5124
#  20         5019
#  16         4266
# -1          4184
#  36         3822
#  7          2914
#  9          2037
#  72         1946
#  100        1819
#  96         1813
#  18         1787
# -2          1395
#  30         1185
#  40         1081
#  32         1047
#  144        1021
#  11          956
#  50          916
#  15          802
#            ...
#  273           1
# -242           1
#  750           1
# -756           1
# -786           1
# -2834          1
# -272           1
#  752           1
# -271           1
#  242           1
# -270           1
# -267           1
#  760           1
#  249           1
#  12540         1
# -1284          1
#  1788          1
#  253           1
#  257           1
#  258           1
# -1277          1
# ...

# %%
data1['product_description'].value_counts()
# Out:
# WHITE HANGING HEART T-LIGHT HOLDER     2369
# REGENCY CAKESTAND 3 TIER               2200
# JUMBO BAG RED RETROSPOT                2159
# PARTY BUNTING                          1727
# LUNCH BAG RED RETROSPOT                1638
# ASSORTED COLOUR BIRD ORNAMENT          1501
# SET OF 3 CAKE TINS PANTRY DESIGN       1473
# PACK OF 72 RETROSPOT CAKE CASES        1385
# LUNCH BAG  BLACK SKULL.                1350
# NATURAL SLATE HEART CHALKBOARD         1280
# POSTAGE                                1252
# JUMBO BAG PINK POLKADOT                1251
# HEART OF WICKER SMALL                  1237
# JAM MAKING SET WITH JARS               1229
# JUMBO STORAGE BAG SUKI                 1214
# PAPER CHAIN KIT 50'S CHRISTMAS         1210
# JUMBO SHOPPER VINTAGE RED PAISLEY      1202
# LUNCH BAG CARS BLUE                    1197
# LUNCH BAG SPACEBOY DESIGN              1192
# JAM MAKING SET PRINTED                 1182
# RECIPE BOX PANTRY YELLOW DESIGN        1180
# ...

# %%
data1.dtypes
# Out:
# transaction_id            object
# product_id                object
# product_description       object
# quantity_sold              int64
# transaction_timestamp     object
# unit_price               float64
# customer_id              float64
# transaction_country       object
# dtype: object

# %%
data1['transaction_timestamp'] = pd.to_datetime(data1['transaction_timestamp'])

# %%
data1.dtypes
# Out:
# transaction_id                   object
# product_id                       object
# product_description              object
# quantity_sold                     int64
# transaction_timestamp    datetime64[ns]
# unit_price                      float64
# customer_id                     float64
# transaction_country              object
# dtype: object

# %%
data1[(data1["transaction_timestamp"].dt.year==2011)]
# Out:
#        transaction_id product_id                  product_description  \
# 42481          539993      22386              JUMBO BAG PINK POLKADOT
# 42482          539993      21499                   BLUE POLKADOT WRAP
# 42483          539993      21498                  RED RETROSPOT WRAP
# 42484          539993      22379             RECYCLING BAG RETROSPOT
# 42485          539993      20718            RED RETROSPOT SHOPPER BAG
# 42486          539993     85099B              JUMBO BAG RED RETROSPOT
# 42487          539993      20682     RED RETROSPOT CHILDRENS UMBRELLA
# 42488          539993      22961               JAM MAKING SET PRINTED
# 42489          539993      22667                RECIPE BOX RETROSPOT
# 42490          539993      22898        CHILDRENS APRON APPLES DESIGN
# 42491          539993      22896                PEG BAG APPLES DESIGN
# 42492          539993      22303             COFFEE MUG APPLES DESIGN
# ...

# %%
data1.groupby(lambda x: data1['transaction_timestamp'][x].year)

# %%
import seaborn as sns
plt.figure(figsize=(10,5))
sns.distplot(data1['quantity_sold'],bins=25)
plt.xlabel('Item_outlet_sales')
plt.ylabel('Number of Sales')
plt.title('Item Outlet Sales Distribution')
plt.grid()
# Out:
# C:\Users\DELL\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\DELL\Anaconda3\lib\site-packages\scipy\stats\stats.py:1706: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
opsd_daily=data1['transaction_timestamp']

# %%
opsd_daily
# Out:
# 0        2010-12-01 08:26:00
# 1        2010-12-01 08:26:00
# 2        2010-12-01 08:26:00
# 3        2010-12-01 08:26:00
# 4        2010-12-01 08:26:00
# 5        2010-12-01 08:26:00
# 6        2010-12-01 08:26:00
# 7        2010-12-01 08:28:00
# 8        2010-12-01 08:28:00
# 9        2010-12-01 08:34:00
# 10       2010-12-01 08:34:00
# 11       2010-12-01 08:34:00
# 12       2010-12-01 08:34:00
# 13       2010-12-01 08:34:00
# 14       2010-12-01 08:34:00
# 15       2010-12-01 08:34:00
# 16       2010-12-01 08:34:00
# 17       2010-12-01 08:34:00
# 18       2010-12-01 08:34:00
# 19       2010-12-01 08:34:00
# 20       2010-12-01 08:34:00
# 21       2010-12-01 08:34:00
# 22       2010-12-01 08:34:00
# 23       2010-12-01 08:34:00
# 24       2010-12-01 08:34:00
# 25       2010-12-01 08:35:00
# 26       2010-12-01 08:45:00
# 27       2010-12-01 08:45:00
# 28       2010-12-01 08:45:00
# 29       2010-12-01 08:45:00
#                  ...
# 541879   2011-12-09 12:31:00
# ...

# %%
opsd_daily.shape
# Out:
# (541909,)

# %%
opsd_daily.index
# Out:
# RangeIndex(start=0, stop=541909, step=1)

# %%
data1['year'] = pd.DatetimeIndex(data1['transaction_timestamp']).year

# %%
data1['year']
# Out:
# 0         2010
# 1         2010
# 2         2010
# 3         2010
# 4         2010
# 5         2010
# 6         2010
# 7         2010
# 8         2010
# 9         2010
# 10        2010
# 11        2010
# 12        2010
# 13        2010
# 14        2010
# 15        2010
# 16        2010
# 17        2010
# 18        2010
# 19        2010
# 20        2010
# 21        2010
# 22        2010
# 23        2010
# 24        2010
# 25        2010
# 26        2010
# 27        2010
# 28        2010
# 29        2010
#           ...
# 541879    2011
# 541880    2011
# 541881    2011
# 541882    2011
# 541883    2011
# 541884    2011
# 541885    2011
# 541886    2011
# 541887    2011
# 541888    2011
# 541889    2011
# 541890    2011
# 541891    2011
# 541892    2011
# 541893    2011
# 541894    2011
# 541895    2011
# 541896    2011
# 541897    2011
# 541898    2011
# 541899    2011
# 541900    2011
# 541901    2011
# 541902    2011
# 541903    2011
# 541904    2011
# 541905    2011
# ...

# %%
data1['quantity_sold'].groupby(data1['year']).agg('count')
# Out:
# year
# 2010     42481
# 2011    499428
# Name: quantity_sold, dtype: int64

# %%
plt.figure(figsize=(10,8))
plt.suptitle('Number of transaction made between 2010 and 2011')
sns.distplot(data1['year'],data1['quantity_sold'].groupby(data1['year']).agg('count'),color='g')
plt.ylim((-2,200))
plt.xlabel('Transaction in year')
plt.ylabel('Number of transaction made')

plt.grid()
# Out:
# C:\Users\DELL\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\DELL\Anaconda3\lib\site-packages\numpy\lib\histograms.py:815: RuntimeWarning: invalid value encountered in true_divide
#   return n/db/n.sum(), bin_edges
# C:\Users\DELL\Anaconda3\lib\site-packages\scipy\stats\stats.py:1706: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
data1['quantity_sold'].groupby(data1['product_description']).agg('count')
# Out:
# product_description
#  4 PURPLE FLOCK DINNER CANDLES          41
#  50'S CHRISTMAS GIFT BAG LARGE         130
#  DOLLY GIRL BEAKER                     181
#  I LOVE LONDON MINI BACKPACK            88
#  I LOVE LONDON MINI RUCKSACK             1
#  NINE DRAWER OFFICE TIDY                34
#  OVAL WALL MIRROR DIAMANTE             162
#  RED SPOT GIFT BAG LARGE               105
#  SET 2 TEA TOWELS I LOVE LONDON        282
#  SPACEBOY BABY GIFT SET                188
#  TOADSTOOL BEDSIDE LIGHT                 1
#  TRELLIS COAT RACK                      58
# *Boombox Ipod Classic                    1
# *USB Office Mirror Ball                  2
# 10 COLOUR SPACEBOY PEN                 327
# 12 COLOURED PARTY BALLOONS             170
# 12 DAISY PEGS IN WOOD BOX               84
# 12 EGG HOUSE PAINTED WOOD              100
# 12 HANGING EGGS HAND PAINTED            10
# 12 IVORY ROSE PEG PLACE SETTINGS       150
# 12 MESSAGE CARDS WITH ENVELOPES        265
# ...

# %%
data1['quantity_sold'].groupby(data1['unit_price']).agg('count')
# Out:
# unit_price
# -11062.060       2
#  0.000        2515
#  0.001           4
#  0.010           1
#  0.030           3
#  0.040          66
#  0.060         117
#  0.070           9
#  0.080          56
#  0.090           2
#  0.100          53
#  0.110           2
#  0.120         641
#  0.140          89
#  0.160          46
#  0.170           8
#  0.180          25
#  0.190        1905
#  0.200          18
#  0.210        1164
#  0.220          13
#  0.240           6
#  0.250          64
#  0.270          16
#  0.280           3
#  0.290        4426
#  0.300          54
#  0.310           9
#  0.320          45
#  0.340          69
#               ...
#  4527.650        1
#  4534.240        1
#  4575.640        1
#  5225.030        1
#  5258.770        1
#  5519.250        1
#  5522.140        1
#  5575.280        1
#  5693.050        1
#  5791.180        1
#  5876.400        1
#  5877.180        1
#  5942.570        2
#  6497.470        1
#  6662.510        1
#  6706.710        1
# ...

# %%
data1['quantity_sold'].groupby(data1['customer_id']).agg('count')
# Out:
# customer_id
# 12346.0      2
# 12347.0    182
# 12348.0     31
# 12349.0     73
# 12350.0     17
# 12352.0     95
# 12353.0      4
# 12354.0     58
# 12355.0     13
# 12356.0     59
# 12357.0    131
# 12358.0     19
# 12359.0    254
# 12360.0    129
# 12361.0     10
# 12362.0    274
# 12363.0     23
# 12364.0     85
# 12365.0     23
# 12367.0     11
# 12370.0    167
# 12371.0     63
# 12372.0     52
# 12373.0     14
# 12374.0     33
# 12375.0     18
# 12377.0     77
# 12378.0    219
# 12379.0     41
# 12380.0    105
#           ...
# 18245.0    177
# 18246.0      4
# 18248.0     49
# 18249.0      8
# 18250.0     22
# 18251.0     16
# 18252.0     98
# 18255.0      6
# 18256.0      4
# 18257.0    123
# 18259.0     42
# 18260.0    140
# 18261.0     21
# 18262.0     13
# 18263.0     62
# 18265.0     46
# 18268.0      2
# 18269.0      8
# 18270.0     13
# 18272.0    170
# 18273.0      3
# 18274.0     22
# 18276.0     16
# 18277.0      9
# 18278.0      9
# 18280.0     10
# 18281.0      7
# ...

# %%
group=data1.groupby(["year","customer_id"]).sum()

# %%
quantity_sold = group["quantity_sold"].groupby(level=0, group_keys=False)

# %%
quantity_sold

# %%
data1.groupby(['customer_id','year'])['quantity_sold'].count()
# Out:
# customer_id  year
# 12346.0      2011      2
# 12347.0      2010     31
#              2011    151
# 12348.0      2010     17
#              2011     14
# 12349.0      2011     73
# 12350.0      2011     17
# 12352.0      2011     95
# 12353.0      2011      4
# 12354.0      2011     58
# 12355.0      2011     13
# 12356.0      2011     59
# 12357.0      2011    131
# 12358.0      2011     19
# 12359.0      2011    254
# 12360.0      2011    129
# 12361.0      2011     10
# 12362.0      2011    274
# 12363.0      2011     23
# 12364.0      2011     85
# 12365.0      2011     23
# 12367.0      2011     11
# 12370.0      2010     91
#              2011     76
# 12371.0      2011     63
# 12372.0      2011     52
# 12373.0      2011     14
# 12374.0      2011     33
# 12375.0      2011     18
# 12377.0      2010     43
#                     ...
# 18248.0      2011     49
# 18249.0      2011      8
# 18250.0      2011     22
# 18251.0      2011     16
# 18252.0      2011     98
# ...

# %%
twowaytable1=pd.crosstab(data1['year'],data1['quantity_sold'])
twowaytable1
# Out:
# quantity_sold  -80995  -74215  -9600   -9360   -9058   -5368   -4830   -3667   \
# year
# 2010                0       0       0       1       0       0       0       0
# 2011                1       1       2       0       1       1       1       1
#
# quantity_sold  -3167   -3114    ...     3114    3186    3906    4000    4300   \
# year                            ...
# 2010                0       0   ...         0       0       0       0       0
# 2011                1       1   ...         2       1       1       1       1
#
# quantity_sold   4800    5568    12540   74215   80995
# year
# 2010                0       0       0       0       0
# 2011                1       1       1       1       1
#
# [2 rows x 722 columns]

# %%
data1.groupby(['customer_id'])['year'].count()
# Out:
# customer_id
# 12346.0      2
# 12347.0    182
# 12348.0     31
# 12349.0     73
# 12350.0     17
# 12352.0     95
# 12353.0      4
# 12354.0     58
# 12355.0     13
# 12356.0     59
# 12357.0    131
# 12358.0     19
# 12359.0    254
# 12360.0    129
# 12361.0     10
# 12362.0    274
# 12363.0     23
# 12364.0     85
# 12365.0     23
# 12367.0     11
# 12370.0    167
# 12371.0     63
# 12372.0     52
# 12373.0     14
# 12374.0     33
# 12375.0     18
# 12377.0     77
# 12378.0    219
# 12379.0     41
# 12380.0    105
#           ...
# 18245.0    177
# 18246.0      4
# 18248.0     49
# 18249.0      8
# 18250.0     22
# 18251.0     16
# 18252.0     98
# 18255.0      6
# 18256.0      4
# 18257.0    123
# 18259.0     42
# 18260.0    140
# 18261.0     21
# 18262.0     13
# 18263.0     62
# 18265.0     46
# 18268.0      2
# 18269.0      8
# 18270.0     13
# 18272.0    170
# 18273.0      3
# 18274.0     22
# 18276.0     16
# 18277.0      9
# 18278.0      9
# 18280.0     10
# 18281.0      7
# ...

# %%
print('Skew is:', data1.quantity_sold.skew())
print('Kurtosis :' , data1.quantity_sold.kurt())
# Out:
# Skew is: -0.2640763070668848
# Kurtosis : 119769.16003068598

# %%
numeric_features = data1.select_dtypes(include=[np.number])
numeric_features.dtypes
# Out:
# quantity_sold      int64
# unit_price       float64
# customer_id      float64
# year               int64
# dtype: object

# %%
corr=numeric_features.corr()
corr
# Out:
#                quantity_sold  unit_price  customer_id      year
# quantity_sold       1.000000   -0.001235    -0.003600  0.002001
# unit_price         -0.001235    1.000000    -0.004560 -0.004586
# customer_id        -0.003600   -0.004560     1.000000 -0.035955
# year                0.002001   -0.004586    -0.035955  1.000000

# %%
print(corr['quantity_sold'].sort_values(ascending=False))
# Out:
# quantity_sold    1.000000
# year             0.002001
# unit_price      -0.001235
# customer_id     -0.003600
# Name: quantity_sold, dtype: float64

# %%
plt.figure(figsize=(10,10))
sns.heatmap(corr, vmax=.02, square=True, annot=True)

# %%
cate_features=data1.select_dtypes(include=np.datetime64)
cate_features.dtypes
# Out:
# transaction_timestamp    datetime64[ns]
# dtype: object

# %%
y=pd.crosstab(index=data1['customer_id'], columns=data1['year'], colnames=['year of transaction from particular candidate id'], margins=True)

# %%
y
# Out:
# year of transaction from particular candidate id   2010    2011     All
# customer_id
# 12346.0                                               0       2       2
# 12347.0                                              31     151     182
# 12348.0                                              17      14      31
# 12349.0                                               0      73      73
# 12350.0                                               0      17      17
# 12352.0                                               0      95      95
# 12353.0                                               0       4       4
# 12354.0                                               0      58      58
# 12355.0                                               0      13      13
# 12356.0                                               0      59      59
# 12357.0                                               0     131     131
# 12358.0                                               0      19      19
# ...

# %%
y=y.drop('All',1)

# %%
y = y.replace(0, np.nan)

# %%
y
# Out:
# year of transaction from particular candidate id     2010      2011
# customer_id
# 12346.0                                               NaN       2.0
# 12347.0                                              31.0     151.0
# 12348.0                                              17.0      14.0
# 12349.0                                               NaN      73.0
# 12350.0                                               NaN      17.0
# 12352.0                                               NaN      95.0
# 12353.0                                               NaN       4.0
# 12354.0                                               NaN      58.0
# 12355.0                                               NaN      13.0
# 12356.0                                               NaN      59.0
# 12357.0                                               NaN     131.0
# 12358.0                                               NaN      19.0
# 12359.0                                               NaN     254.0
# ...

# %%
y=y[(y[2010].notnull())&(y[2011].notnull())]

# %%
x=y.drop('All')

# %%
x
# Out:
# year of transaction from particular candidate id   2010    2011
# customer_id
# 12347.0                                            31.0   151.0
# 12348.0                                            17.0    14.0
# 12370.0                                            91.0    76.0
# 12377.0                                            43.0    34.0
# 12383.0                                            37.0    63.0
# 12386.0                                             8.0     2.0
# 12395.0                                            31.0   128.0
# 12417.0                                            11.0   187.0
# 12423.0                                            16.0   110.0
# 12427.0                                            13.0    22.0
# 12429.0                                            20.0    77.0
# 12431.0                                            24.0   216.0
# 12433.0                                           147.0   273.0
# ...

# %%
y
# Out:
# year of transaction from particular candidate id     2010      2011
# customer_id
# 12347.0                                              31.0     151.0
# 12348.0                                              17.0      14.0
# 12370.0                                              91.0      76.0
# 12377.0                                              43.0      34.0
# 12383.0                                              37.0      63.0
# 12386.0                                               8.0       2.0
# 12395.0                                              31.0     128.0
# 12417.0                                              11.0     187.0
# 12423.0                                              16.0     110.0
# 12427.0                                              13.0      22.0
# 12429.0                                              20.0      77.0
# 12431.0                                              24.0     216.0
# 12433.0                                             147.0     273.0
# ...

# %%
fig, axs = plt.subplots()

x[2010].plot(color="green")
x[2011].plot(color="red")

# %%
fig = plt.figure(figsize=(120,10))
fig, axs = plt.subplots(1,2)

x[2010].plot(ax=axs[0],title="count of transactions made by customer in 2010")
x[2011].plot(ax=axs[1],title="count of transactions made by customer in 2011")
sns.despine
# Out:
# <function seaborn.utils.despine>

# %%
x[-15:].plot( y=[2010, 2011], figsize=(15,5), grid=True)
plt.title('Transaction made in the particular year')
plt.xlabel('Candiate Id')
plt.ylabel('Count of Transaction made')
sns.despine
# Out:
# C:\Users\DELL\Anaconda3\lib\site-packages\pandas\plotting\_core.py:1716: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   series.name = label
# <function seaborn.utils.despine>

# %%
x[-10:].plot( y=[2010, 2011], figsize=(10,5), grid=True, kind='bar')
plt.title('Transaction made in the particular year')
plt.xlabel('Candidate')
plt.ylabel('Count of Transaction made')
sns.despine
plt.show()
# Out:
# C:\Users\DELL\Anaconda3\lib\site-packages\pandas\plotting\_core.py:1716: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   series.name = label

# %%
import base64
x.to_csv("test1.csv")

# %%
from IPython.display import HTML

def create_download_link( y, title = "Download CSV file", filename = "data.csv"):  
    csv = y.to_csv()
    b64 = base64.b64encode(csv.encode())
    payload = b64.decode()
    html = '<a download="{filename}" href="data:text/csv;base64,{payload}" target="_blank">{title}</a>'
    html = html.format(payload=payload,title=title,filename=filename)
    return HTML(html)

create_download_link(y)
# Out:
# <a download="data.csv" href="data:text/csv;base64,..." target="_blank">Download CSV file</a>

# %%
data1.head()
# Out:
#   transaction_id product_id                  product_description  \
# 0         536365     85123A   WHITE HANGING HEART T-LIGHT HOLDER
# 1         536365      71053                  WHITE METAL LANTERN
# 2         536365     84406B       CREAM CUPID HEARTS COAT HANGER
# 3         536365     84029G  KNITTED UNION FLAG HOT WATER BOTTLE
# 4         536365     84029E       RED WOOLLY HOTTIE WHITE HEART.
#
#    quantity_sold transaction_timestamp  unit_price  customer_id  \
# 0              6   2010-12-01 08:26:00        2.55      17850.0
# 1              6   2010-12-01 08:26:00        3.39      17850.0
# 2              8   2010-12-01 08:26:00        2.75      17850.0
# 3              6   2010-12-01 08:26:00        3.39      17850.0
# 4              6   2010-12-01 08:26:00        3.39      17850.0
#
#   transaction_country  year
# 0      United Kingdom  2010
# 1      United Kingdom  2010
# 2      United Kingdom  2010
# 3      United Kingdom  2010
# 4      United Kingdom  2010

# %%
# to get 3 random rows
# each time you run this, you would have 3 different rows
data1.sample(n=20)
# Out:
#        transaction_id product_id                 product_description  \
# 381588         569868      23539             WALL ART LOVES' SECRET
# 385027         570187      22619           SET OF 6 SOLDIER SKITTLES
# 528776         580729     90165B       WHITE ROSEBUD  PEARL EARRINGS
# 325049         565430      22375   AIRLINE BAG VINTAGE JET SET BROWN
# 322117         565226      20765           CHRYSANTHEMUM SKETCHBOOK
# 403308         571560      23145      ZINC T-LIGHT HOLDER STAR LARGE
# 428862         573501      22689        DOORMAT MERRY CHRISTMAS RED
# 141851         548522      22798    ANTIQUE GLASS DRESSING TABLE POT
# 204029         554628      20711                     JUMBO BAG TOYS
# 166680         550953      85187             S/12 MINI RABBIT EASTER
# 509977         579412      23029     DRAWER KNOB CRACKLE GLAZE GREEN
# 407821         571910      23480      MINI LIGHTS WOODLAND MUSHROOMS
# 7619           537047      22662         LUNCH BAG DOLLY GIRL DESIGN
# ...

# %%
data1.sample(n=3, random_state=5)
# Out:
#        transaction_id product_id             product_description  \
# 371060         569209      23284   DOORMAT KEEP CALM AND COME IN
# 384445         570125      23296  SET OF 6 TEA TIME BAKING CASES
# 605            536412      22902          TOTE BAG I LOVE LONDON
#
#         quantity_sold transaction_timestamp  unit_price  customer_id  \
# 371060              2   2011-10-02 11:30:00        8.25      16626.0
# 384445              8   2011-10-07 13:14:00        1.25      17509.0
# 605                 7   2010-12-01 11:49:00        2.10      17920.0
#
#        transaction_country  year
# 371060      United Kingdom  2011
# 384445      United Kingdom  2011
# 605         United Kingdom  2010

# %%
data1.sample(frac=0.75, random_state=99)
# Out:
#        transaction_id product_id                  product_description  \
# 445659         574856      22649         STRAWBERRY FAIRY CAKE TEAPOT
# 536404         581219      10135         COLOURING PENCILS BROWN TUBE
# 280709         561485      47566                        PARTY BUNTING
# 402811         571508      23085         ANTIQUE SILVER BAUBLE LAMP
# 58766          541262      21464  DISCO BALL ROTATOR BATTERY OPERATED
# 515915         579792      22752         SET 7 BABUSHKA NESTING BOXES
# 505431         579067      23242           TREASURE TIN BUFFALO BILL
# 336119         566304      22661      CHARLOTTE BAG DOLLY GIRL DESIGN
# 92850          544206      20725              LUNCH BAG RED RETROSPOT
# 167492         550989      23199                     JUMBO BAG APPLES
# 264465         560097      21391          FRENCH LAVENDER SCENT HEART
# 33273          539245      22909  SET OF 20 VINTAGE CHRISTMAS NAPKINS
# ...

# %%
train = data1.sample(frac=0.75, random_state=99)

# %%
# you can't simply split 0.75 and 0.25 without overlapping
# this code tries to find that train = 75% and test = 25%
test = data1.loc[~data1.index.isin(train.index), :]

# %%
df_idf=data1

# print schema
print("Schema:\n\n",df_idf.dtypes)
print("Number of questions,columns=",df_idf.shape)
# Out:
# Schema:
#
#  transaction_id                   object
# product_id                       object
# product_description              object
# quantity_sold                     int64
# transaction_timestamp    datetime64[ns]
# unit_price                      float64
# customer_id                     float64
# transaction_country              object
# year                              int64
# dtype: object
# Number of questions,columns= (541909, 9)

# %%
df_idf['text'] = df_idf['product_description']
df_idf['text'][2]
# Out:
# 'CREAM CUPID HEARTS COAT HANGER'
